# %%
# height and weight prediction by using the linearregression

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
weight = pd.read_csv("C:/Users/Harsha Vardhan/Downloads/weight-height.csv")

# %%
weight
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
#label encoding the data

# %%
weight.replace({"Gender":{"Male":0,"Female":1}},inplace=True)

# %%
weight
# Out:
#       Gender     Height      Weight
# 0          0  73.847017  241.893563
# 1          0  68.781904  162.310473
# 2          0  74.110105  212.740856
# 3          0  71.730978  220.042470
# 4          0  69.881796  206.349801
# ...      ...        ...         ...
# 9995       1  66.172652  136.777454
# 9996       1  67.067155  170.867906
# 9997       1  63.867992  128.475319
# 9998       1  69.034243  163.852461
# 9999       1  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
x = weight.drop("Weight",axis=1)
y=weight["Weight"]

# %%
#splitting the data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=4)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics

# %%
error_value = metrics.r2_score(y_test,y_pred)
error_value
# Out:
# 0.9019621077541354

# %%
plt.scatter(y_test,y_pred)
plt.plot(y_test,y_pred,color="red")
plt.xlabel("actual value")
plt.ylabel("predicted value")
plt.title("actual value VS predicted value")
plt.show()

# %%
compare_data = pd.DataFrame({"actual_values":y_test,"predicted_value":y_pred})

# %%
comapre_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 comapre_data
#
# NameError: name 'comapre_data' is not defined
