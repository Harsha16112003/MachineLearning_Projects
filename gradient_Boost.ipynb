# %%
import sklearn

# %%
from sklearn import datasets

# %%
diabetes = datasets.load_diabetes()

# %%
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
x = diabetes.data

# %%
y=diabetes.target

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=17)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model = GradientBoostingRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array([194.32032376, 204.61717086,  82.0018637 , 130.86247372,
#        111.33153344,  76.6423696 ,  86.89034615,  88.85289012,
#        120.10869056,  79.68953687, 243.00349771, 151.15175558,
#         99.63410967, 118.20567078, 201.30811708, 212.80378753,
#        171.03095723, 160.83752537, 240.78801495, 149.95333153,
#        185.04005134, 271.14754826, 211.00187526,  74.36259705,
#        107.4080602 , 188.57216198, 122.9434143 , 171.2700464 ,
#         88.71925556, 240.40521301,  77.31003687,  74.58684143,
#         88.53916485, 306.87165016, 179.26613354, 156.15091951,
#         88.65453919, 164.95309246,  86.8576877 , 235.01224675,
#        108.1147595 ,  92.18266071, 192.72339152, 311.70248473,
#        154.00969817,  95.77146447, 182.75628787, 118.62128605,
#        203.10649199, 190.07207016, 202.64200732, 168.55390416,
#        172.60684686, 139.96279601, 183.918274  , 134.84039637,
#         89.6715148 , 309.14287254, 137.29693356, 158.77717144,
#        172.20835146, 239.36114805,  90.49086262, 149.16190291,
#        105.36303146,  88.76257353, 202.98970957,  79.9060424 ,
#        172.17979429, 165.1252003 , 124.00230302, 276.27767686,
#        278.36552221, 184.27883678, 107.5169015 , 124.76354255,
#        199.15490749, 168.94654158, 129.53450696, 142.64336417,
#        278.18754006,  92.30382841, 133.99646158,  69.19207751,
#        271.87930406, 306.73167968,  93.44156276, 103.37605531,
#         84.15126113, 236.67659504, 206.44291833, 115.82317222,
#        157.23771336, 125.05498767,  87.1060032 , 102.60456556,
#         83.14212999, 283.10088179, 157.29293871, 139.04986063,
#        215.54204529,  99.27081676,  74.63613633, 159.0400537 ,
#        107.8867342 , 188.16617737, 204.63324067, 116.18892646,
#        192.5867406 , 201.60100273, 241.49620356, 257.79660206,
#         68.34721451, 143.25755542, 113.7599834 , 192.10997041,
#        213.23727467, 183.90035428, 100.05997927,  96.44318816,
#        127.78108127, 161.63196747, 162.32197502, 195.22405055,
#        116.38332109, 236.84458206, 129.7521525 , 134.59093661,
#         74.3829759 ,  80.86951398, 270.28789481, 198.62590503,
#         90.9769609 ])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_absolute_error(y_test,pred)
# Out:
# 45.2779232306068

# %%
mean_squared_error(y_test,pred)
# Out:
# 3291.5958912205238

# %%
r2_score(y_test,pred)
# Out:
# 0.4215477434565561

# %%
param_grid = {
    'n_estimators':[100,200,300],
    'learning_rate':[0.01,0.05,0.1],
    'max_depth':[3,4,5],
    'min_samples_split':[2,3,4],
    'min_samples_leaf':[1,2,3],
    }

# %%
from sklearn.model_selection import GridSearchCV

# %%
gbr = GridSearchCV(model,param_grid,cv=3,n_jobs=-1)

# %%
gbr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 200, 300]})

# %%
g_pred =gbr.predict(x_test)

# %%
mean_absolute_error(y_test,g_pred)
# Out:
# 44.483267367166206

# %%
mean_squared_error(y_test,g_pred)
# Out:
# 3060.7488230120125

# %%
r2_score(y_test,g_pred)
# Out:
# 0.4621159091532683
