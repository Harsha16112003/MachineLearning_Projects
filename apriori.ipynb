# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\harsha vardhan\anaconda\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\harsha vardhan\anaconda\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\harsha vardhan\anaconda\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\harsha vardhan\anaconda\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\harsha vardhan\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harsha vardhan\anaconda\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\harsha vardhan\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
import mlxtend

# %%
print(mlxtend.__version__)
# Out:
# 0.23.4

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# #

# %%
dataset = [["Milk","Onion","Nutmeg","Kidney Beans","Eggs","Yogurt"],
          ["Dill","Onion","Nutmeg","Kidney Beans","Eggs","Yogurt"],
          ["Milk","Apple","Kidney Beans","Eggs"],
           ["Milk","Unicorn","Corn","Kidney Beans","Yogurt"],
          ["Corn","Onion","Onion","Kidney Beans","Ice cream","Eggs"]]

# %% [markdown]
# * Data preprocessing using by mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
dataset
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
te_ary
# Out:
# array([[False, False, False,  True, False,  True,  True,  True,  True,
#         False,  True],
#        [False, False,  True,  True, False,  True, False,  True,  True,
#         False,  True],
#        [ True, False, False,  True, False,  True,  True, False, False,
#         False, False],
#        [False,  True, False, False, False,  True,  True, False, False,
#          True,  True],
#        [False,  True, False,  True,  True,  True, False, False,  True,
#         False, False]])

# %%
df = pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_items = apriori(df,min_support=0.6,use_colnames=True)
frequent_items
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Kidney Beans, Eggs)
# 6       0.6                (Onion, Eggs)
# 7       0.6         (Kidney Beans, Milk)
# 8       0.6        (Onion, Kidney Beans)
# 9       0.6       (Yogurt, Kidney Beans)
# 10      0.6  (Onion, Kidney Beans, Eggs)

# %% [markdown]
# # Association rule mining

# %%
from mlxtend.frequent_patterns import association_rules

# %%
res = association_rules(frequent_items,metric="confidence",min_threshold=0.7)
# Out:
# C:\Users\Harsha Vardhan\anaconda\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)

# %%
res
# Out:
#               antecedents            consequents  antecedent support  \
# 0          (Kidney Beans)                 (Eggs)                 1.0
# 1                  (Eggs)         (Kidney Beans)                 0.8
# 2                 (Onion)                 (Eggs)                 0.6
# 3                  (Eggs)                (Onion)                 0.8
# 4                  (Milk)         (Kidney Beans)                 0.6
# 5                 (Onion)         (Kidney Beans)                 0.6
# 6                (Yogurt)         (Kidney Beans)                 0.6
# 7   (Onion, Kidney Beans)                 (Eggs)                 0.6
# 8           (Onion, Eggs)         (Kidney Beans)                 0.6
# 9    (Kidney Beans, Eggs)                (Onion)                 0.8
# 10                (Onion)   (Kidney Beans, Eggs)                 0.6
# 11                 (Eggs)  (Onion, Kidney Beans)                 0.8
#
#     consequent support  support  confidence  lift  representativity  leverage  \
# 0                  0.8      0.8        0.80  1.00               1.0      0.00
# 1                  1.0      0.8        1.00  1.00               1.0      0.00
# 2                  0.8      0.6        1.00  1.25               1.0      0.12
# 3                  0.6      0.6        0.75  1.25               1.0      0.12
# 4                  1.0      0.6        1.00  1.00               1.0      0.00
# 5                  1.0      0.6        1.00  1.00               1.0      0.00
# 6                  1.0      0.6        1.00  1.00               1.0      0.00
# 7                  0.8      0.6        1.00  1.25               1.0      0.12
# 8                  1.0      0.6        1.00  1.00               1.0      0.00
# 9                  0.6      0.6        0.75  1.25               1.0      0.12
# 10                 0.8      0.6        1.00  1.25               1.0      0.12
# 11                 0.6      0.6        0.75  1.25               1.0      0.12
#
#     conviction  zhangs_metric  jaccard  certainty  kulczynski
# 0          1.0            0.0     0.80      0.000       0.900
# 1          inf            0.0     0.80      0.000       0.900
# 2          inf            0.5     0.75      1.000       0.875
# 3          1.6            1.0     0.75      0.375       0.875
# 4          inf            0.0     0.60      0.000       0.800
# 5          inf            0.0     0.60      0.000       0.800
# 6          inf            0.0     0.60      0.000       0.800
# 7          inf            0.5     0.75      1.000       0.875
# 8          inf            0.0     0.60      0.000       0.800
# 9          1.6            1.0     0.75      0.375       0.875
# 10         inf            0.5     0.75      1.000       0.875
# 11         1.6            1.0     0.75      0.375       0.875

# %%
res1 = res[["antecedents","consequents","support","confidence","lift"]]
res1
# Out:
#               antecedents            consequents  support  confidence  lift
# 0          (Kidney Beans)                 (Eggs)      0.8        0.80  1.00
# 1                  (Eggs)         (Kidney Beans)      0.8        1.00  1.00
# 2                 (Onion)                 (Eggs)      0.6        1.00  1.25
# 3                  (Eggs)                (Onion)      0.6        0.75  1.25
# 4                  (Milk)         (Kidney Beans)      0.6        1.00  1.00
# 5                 (Onion)         (Kidney Beans)      0.6        1.00  1.00
# 6                (Yogurt)         (Kidney Beans)      0.6        1.00  1.00
# 7   (Onion, Kidney Beans)                 (Eggs)      0.6        1.00  1.25
# 8           (Onion, Eggs)         (Kidney Beans)      0.6        1.00  1.00
# 9    (Kidney Beans, Eggs)                (Onion)      0.6        0.75  1.25
# 10                (Onion)   (Kidney Beans, Eggs)      0.6        1.00  1.25
# 11                 (Eggs)  (Onion, Kidney Beans)      0.6        0.75  1.25

# %%
res2 =res1[res1["confidence"]>=1]
res2
# Out:
#               antecedents           consequents  support  confidence  lift
# 1                  (Eggs)        (Kidney Beans)      0.8         1.0  1.00
# 2                 (Onion)                (Eggs)      0.6         1.0  1.25
# 4                  (Milk)        (Kidney Beans)      0.6         1.0  1.00
# 5                 (Onion)        (Kidney Beans)      0.6         1.0  1.00
# 6                (Yogurt)        (Kidney Beans)      0.6         1.0  1.00
# 7   (Onion, Kidney Beans)                (Eggs)      0.6         1.0  1.25
# 8           (Onion, Eggs)        (Kidney Beans)      0.6         1.0  1.00
# 10                (Onion)  (Kidney Beans, Eggs)      0.6         1.0  1.25
